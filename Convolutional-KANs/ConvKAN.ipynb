# %%
#@markdown # Connect Google Drive
from google.colab import drive
from IPython.display import clear_output
import ipywidgets as widgets
def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
Shared_Drive = "" #@param {type:"string"}
#@markdown - Leave empty if you're not using a shared drive

print("Connecting...")
drive.mount('/content/gdrive')

if Shared_Drive!="" and os.path.exists("/content/gdrive/Shareddrives"):
  mainpth="Shareddrives/"+Shared_Drive
else:
  mainpth="MyDrive"

clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
# !pip install torchinfo torchmetrics accelerate wandb

# %%
# %cd /content/gdrive/MyDrive/FAIR/2024/
# Out:
# /content/gdrive/MyDrive/FAIR/2024

# %%
# !git clone https://github.com/AntonioTepsich/Convolutional-KANs.git
# Out:
# Cloning into 'Convolutional-KANs'...
# remote: Enumerating objects: 1531, done.
# remote: Counting objects: 100% (377/377), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 1531 (delta 250), reused 344 (delta 221), pack-reused 1154
# Receiving objects: 100% (1531/1531), 33.38 MiB | 10.11 MiB/s, done.
# Resolving deltas: 100% (724/724), done.

# %%
# !ls -la
# Out:
# total 202
# drwx------ 2 root root   4096 Jul  1 14:59 architectures_28x28
# -rw------- 1 root root    560 Jul  1 14:59 experiment_28x28.csv
# -rw------- 1 root root 176477 Jul  1 14:59 experiment_28x28.ipynb
# drwx------ 8 root root   4096 Jul  1 14:59 .git
# -rw------- 1 root root     41 Jul  1 14:59 .gitignore
# drwx------ 2 root root   4096 Jul  1 14:59 images
# drwx------ 2 root root   4096 Jul  1 14:59 kan_convolutional
# -rw------- 1 root root   1126 Jul  1 14:59 LICENSE
# -rw------- 1 root root   9663 Jul  1 14:59 README.md
# -rw------- 1 root root    139 Jul  1 14:59 requirements.txt

# %%
# %cd /content/gdrive/MyDrive/FAIR/2024/Convolutional-KANs
# Out:
# /content/gdrive/MyDrive/FAIR/2024/Convolutional-KANs

# %%
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib==3.6.2 (from -r requirements.txt (line 1))
#   Downloading matplotlib-3.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 27.3 MB/s eta 0:00:00
# Collecting numpy==1.26.4 (from -r requirements.txt (line 2))
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 42.0 MB/s eta 0:00:00
# Collecting pandas==2.2.2 (from -r requirements.txt (line 3))
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 38.9 MB/s eta 0:00:00
# Collecting scikit-learn==1.4.2 (from -r requirements.txt (line 4))
#   Downloading scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 33.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm==4.66.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (4.66.4)
# ERROR: Could not find a version that satisfies the requirement torch==2.3.0+cu118 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1)
# ERROR: No matching distribution found for torch==2.3.0+cu118

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader

from architectures.CKAN_BN import CKAN_BN
from architectures.SimpleModels import *
from architectures.ConvNet import ConvNet
from architectures.KANConvs_MLP import KANC_MLP
from architectures.KKAN import KKAN_Convolutional_Network
from architectures.conv_and_kan import NormalConvsKAN
